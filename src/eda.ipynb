# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Exploratory Data Analysis
#
# ## BIG 5

# %%
df = pd.read_csv("data/BIG5/data.csv", sep='\t')
df.head()
# Out:
#    race  age  engnat  gender  hand  source country  E1  E2  E3  ...  O1  O2  \
# 0     3   53       1       1     1       1      US   4   2   5  ...   4   1
# 1    13   46       1       2     1       1      US   2   2   3  ...   3   3
# 2     1   14       2       2     1       1      PK   5   1   1  ...   4   5
# 3     3   19       2       2     1       1      RO   2   5   2  ...   4   3
# 4    11   25       2       2     1       2      US   3   1   3  ...   3   1
#
#    O3  O4  O5  O6  O7  O8  O9  O10
# 0   3   1   5   1   4   2   5    5
# 1   3   3   2   3   3   1   3    2
# 2   5   1   5   1   5   5   5    5
# 3   5   2   4   2   5   2   5    5
# 4   1   1   3   1   3   1   5    3
#
# [5 rows x 57 columns]

# %%
print("Shape:" , df.shape)
print("Columns:", list(df.columns))
print(len(list(df.columns)))
print(df.info())
# Out:
# Shape: (19719, 57)
# Columns: ['race', 'age', 'engnat', 'gender', 'hand', 'source', 'country', 'E1', 'E2', 'E3', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'O1', 'O2', 'O3', 'O4', 'O5', 'O6', 'O7', 'O8', 'O9', 'O10']
# 57
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19719 entries, 0 to 19718
# Data columns (total 57 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   race     19719 non-null  int64
#  1   age      19719 non-null  int64
#  2   engnat   19719 non-null  int64
#  3   gender   19719 non-null  int64
#  4   hand     19719 non-null  int64
#  5   source   19719 non-null  int64
#  6   country  19710 non-null  object
#  7   E1       19719 non-null  int64
#  8   E2       19719 non-null  int64
#  9   E3       19719 non-null  int64
# ...

# %%
df.describe()
# Out:
#                race           age        engnat        gender          hand  \
# count  19719.000000  1.971900e+04  19719.000000  19719.000000  19719.000000
# mean       5.324205  5.076703e+04      1.365130      1.616918      1.130128
# std        4.019064  7.121272e+06      0.488796      0.499122      0.413663
# min        0.000000  1.300000e+01      0.000000      0.000000      0.000000
# 25%        3.000000  1.800000e+01      1.000000      1.000000      1.000000
# 50%        3.000000  2.200000e+01      1.000000      2.000000      1.000000
# 75%        8.000000  3.100000e+01      2.000000      2.000000      1.000000
# max       13.000000  1.000000e+09      2.000000      3.000000      3.000000
#
#             source            E1            E2            E3            E4  \
# count  19719.00000  19719.000000  19719.000000  19719.000000  19719.000000
# mean       1.95228      2.628937      2.759724      3.416755      3.152036
# ...

# %%
reverse_values_dict = { 5:1 , 4:2 ,3:3 , 2:4, 1:5}
changed_qs = ['E2', 'E4', 'E6', 'E8', 'E10', 'N2', 'N4', 'A1', 'A3', 'A5', 'A7', 'C2', 'C4', 'C6', 'C8', 'O2', 'O4', 'O6']
for col in df.iloc[:, 7:]:
    if col in changed_qs:
      df.replace({col: reverse_values_dict})
    else:
      pass

# %%
df.head()
# Out:
#    race  age  engnat  gender  hand  source country  E1  E2  E3  ...  O1  O2  \
# 0     3   53       1       1     1       1      US   4   2   5  ...   4   1
# 1    13   46       1       2     1       1      US   2   2   3  ...   3   3
# 2     1   14       2       2     1       1      PK   5   1   1  ...   4   5
# 3     3   19       2       2     1       1      RO   2   5   2  ...   4   3
# 4    11   25       2       2     1       2      US   3   1   3  ...   3   1
#
#    O3  O4  O5  O6  O7  O8  O9  O10
# 0   3   1   5   1   4   2   5    5
# 1   3   3   2   3   3   1   3    2
# 2   5   1   5   1   5   5   5    5
# 3   5   2   4   2   5   2   5    5
# 4   1   1   3   1   3   1   5    3
#
# [5 rows x 57 columns]

# %%
df.describe()
# Out:
#                race           age        engnat        gender          hand  \
# count  19719.000000  1.971900e+04  19719.000000  19719.000000  19719.000000
# mean       5.324205  5.076703e+04      1.365130      1.616918      1.130128
# std        4.019064  7.121272e+06      0.488796      0.499122      0.413663
# min        0.000000  1.300000e+01      0.000000      0.000000      0.000000
# 25%        3.000000  1.800000e+01      1.000000      1.000000      1.000000
# 50%        3.000000  2.200000e+01      1.000000      2.000000      1.000000
# 75%        8.000000  3.100000e+01      2.000000      2.000000      1.000000
# max       13.000000  1.000000e+09      2.000000      3.000000      3.000000
#
#             source            E1            E2            E3            E4  \
# count  19719.00000  19719.000000  19719.000000  19719.000000  19719.000000
# mean       1.95228      2.628937      2.759724      3.416755      3.152036
# ...

# %% [markdown]
# # Exploratory Data Analysis
#
# ## myPersonality

# %%
df2 = pd.read_csv("data/myPersonality/mypersonality_final.csv", encoding = "ISO-8859-1")
df2.head()
# Out:
#                             #AUTHID  \
# 0  b7b7764cfa1c523e4e93ab2a79a946c4
# 1  b7b7764cfa1c523e4e93ab2a79a946c4
# 2  b7b7764cfa1c523e4e93ab2a79a946c4
# 3  b7b7764cfa1c523e4e93ab2a79a946c4
# 4  b7b7764cfa1c523e4e93ab2a79a946c4
#
#                                               STATUS  sEXT  sNEU  sAGR  sCON  \
# 0                        likes the sound of thunder.  2.65   3.0  3.15  3.25
# 1  is so sleepy it's not even funny that's she ca...  2.65   3.0  3.15  3.25
# 2  is sore and wants the knot of muscles at the b...  2.65   3.0  3.15  3.25
# 3         likes how the day sounds in this new song.  2.65   3.0  3.15  3.25
# 4                                        is home. <3  2.65   3.0  3.15  3.25
#
#    sOPN cEXT cNEU cAGR cCON cOPN               DATE  NETWORKSIZE  BETWEENNESS  \
# 0   4.4    n    y    n    n    y  06/19/09 03:21 PM        180.0      14861.6
# 1   4.4    n    y    n    n    y  07/02/09 08:41 AM        180.0      14861.6
# ...

# %%
print("Shape:" , df2.shape)
print("Columns:", list(df2.columns))
print(len(list(df2.columns)))
print(df2.info())
# Out:
# Shape: (9917, 20)
# Columns: ['#AUTHID', 'STATUS', 'sEXT', 'sNEU', 'sAGR', 'sCON', 'sOPN', 'cEXT', 'cNEU', 'cAGR', 'cCON', 'cOPN', 'DATE', 'NETWORKSIZE', 'BETWEENNESS', 'NBETWEENNESS', 'DENSITY', 'BROKERAGE', 'NBROKERAGE', 'TRANSITIVITY']
# 20
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9917 entries, 0 to 9916
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #AUTHID       9917 non-null   object
#  1   STATUS        9917 non-null   object
#  2   sEXT          9917 non-null   float64
#  3   sNEU          9917 non-null   float64
#  4   sAGR          9917 non-null   float64
#  5   sCON          9917 non-null   float64
#  6   sOPN          9917 non-null   float64
#  7   cEXT          9917 non-null   object
#  8   cNEU          9917 non-null   object
#  9   cAGR          9917 non-null   object
#  10  cCON          9917 non-null   object
#  11  cOPN          9917 non-null   object
# ...

# %%
df2.describe()
# Out:
#               sEXT         sNEU         sAGR         sCON         sOPN  \
# count  9917.000000  9917.000000  9917.000000  9917.000000  9917.000000
# mean      3.354760     2.609453     3.616643     3.474201     4.130386
# std       0.857578     0.760248     0.682485     0.737215     0.585672
# min       1.330000     1.250000     1.650000     1.450000     2.250000
# 25%       2.710000     2.000000     3.140000     3.000000     3.750000
# 50%       3.400000     2.600000     3.650000     3.400000     4.250000
# 75%       4.000000     3.050000     4.150000     4.000000     4.550000
# max       5.000000     4.750000     5.000000     5.000000     5.000000
#
#         NETWORKSIZE   BETWEENNESS  NBETWEENNESS       DENSITY     BROKERAGE  \
# count   9917.000000  9.917000e+03   9917.000000   9917.000000  9.917000e+03
# mean     429.377120  1.354253e+05     94.665170      3.154012  1.376425e+05
# std      428.760382  1.994338e+05      5.506696    311.073343  2.013921e+05
# ...
